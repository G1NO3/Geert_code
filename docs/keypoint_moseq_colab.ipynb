# %% [markdown]
# This notebook shows how to setup a new project, train a keypoint-MoSeq model and visualize the resulting syllables.
#
# **Total run time: ~90 min.**
#
# # Colab setup
#
# - Make a copy of this notebook if you plan to make changes and want them saved.
# - Go to "Runtime">"change runtime type" and select "Python 3" and "GPU"

# %% [markdown]
# ### Install keypoint MoSeq

# %%
! pip install -U keypoint-moseq
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: keypoint-moseq in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: seaborn==0.13.0 in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.13.0)
# Requirement already satisfied: cytoolz in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (1.0.1)
# Requirement already satisfied: matplotlib==3.8.4 in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (3.8.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (4.67.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (5.5.6)
# Requirement already satisfied: imageio[ffmpeg] in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (2.36.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.14.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (6.0.2)
# Requirement already satisfied: vidio in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.0.4)
# Requirement already satisfied: holoviews[recommended] in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (1.15.4)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (2.4.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (2.2.2)
# Requirement already satisfied: tables in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (3.10.1)
# Requirement already satisfied: panel==0.14.4 in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.14.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (3.4.2)
# Requirement already satisfied: sleap-io in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.2.0)
# Requirement already satisfied: pynwb in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (2.8.3)
# Requirement already satisfied: ndx-pose in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.1.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (5.24.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.2.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.9.0)
# Requirement already satisfied: commentjson in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.9.0)
# Requirement already satisfied: jax-moseq>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (0.3.0)
# Requirement already satisfied: numpy<=1.26.4 in /usr/local/lib/python3.10/dist-packages (from keypoint-moseq) (1.26.4)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh->keypoint-moseq) (3.1.4)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh->keypoint-moseq) (24.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh->keypoint-moseq) (11.0.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh->keypoint-moseq) (6.3.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from bokeh->keypoint-moseq) (4.12.2)
# Requirement already satisfied: param<2.0,>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from holoviews[recommended]->keypoint-moseq) (1.13.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.10/dist-packages (from holoviews[recommended]->keypoint-moseq) (3.0.3)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.10/dist-packages (from holoviews[recommended]->keypoint-moseq) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.4->keypoint-moseq) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.4->keypoint-moseq) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.4->keypoint-moseq) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.4->keypoint-moseq) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.4->keypoint-moseq) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.4->keypoint-moseq) (2.8.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from panel==0.14.4->keypoint-moseq) (3.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from panel==0.14.4->keypoint-moseq) (2.32.3)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from panel==0.14.4->keypoint-moseq) (0.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from panel==0.14.4->keypoint-moseq) (6.2.0)
# Requirement already satisfied: setuptools>=42 in /usr/local/lib/python3.10/dist-packages (from panel==0.14.4->keypoint-moseq) (75.1.0)
# Requirement already satisfied: numba>=0.56.4 in /usr/local/lib/python3.10/dist-packages (from jax-moseq>=0.2.2->keypoint-moseq) (0.60.0)
# Requirement already satisfied: dynamax>=0.1.2 in /usr/local/lib/python3.10/dist-packages (from jax-moseq>=0.2.2->keypoint-moseq) (0.1.5)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from jax-moseq>=0.2.2->keypoint-moseq) (0.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->keypoint-moseq) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->keypoint-moseq) (2024.2)
# Requirement already satisfied: lark-parser<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from commentjson->keypoint-moseq) (0.7.8)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz->keypoint-moseq) (0.12.1)
# Requirement already satisfied: ipython>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from holoviews[recommended]->keypoint-moseq) (7.34.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from holoviews[recommended]->keypoint-moseq) (6.5.5)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (from imageio[ffmpeg]->keypoint-moseq) (0.5.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from imageio[ffmpeg]->keypoint-moseq) (5.9.5)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->keypoint-moseq) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->keypoint-moseq) (6.1.12)
# Requirement already satisfied: hdmf<4,>=2.5.6 in /usr/local/lib/python3.10/dist-packages (from ndx-pose->keypoint-moseq) (3.14.6)
# Requirement already satisfied: h5py>=2.10 in /usr/local/lib/python3.10/dist-packages (from pynwb->keypoint-moseq) (3.12.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->keypoint-moseq) (9.0.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from sleap-io->keypoint-moseq) (24.3.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from sleap-io->keypoint-moseq) (3.19.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.10/dist-packages (from statsmodels->keypoint-moseq) (1.13.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->keypoint-moseq) (1.0.1)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables->keypoint-moseq) (2.10.2)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables->keypoint-moseq) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from tables->keypoint-moseq) (2.7.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from vidio->keypoint-moseq) (4.10.0.84)
# Requirement already satisfied: ndindex>=1.4 in /usr/local/lib/python3.10/dist-packages (from blosc2>=2.3.0->tables->keypoint-moseq) (1.9.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from blosc2>=2.3.0->tables->keypoint-moseq) (1.1.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.4.33)
# Requirement already satisfied: fastprogress in /usr/local/lib/python3.10/dist-packages (from dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (1.0.3)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.2.4)
# Requirement already satisfied: tensorflow-probability in /usr/local/lib/python3.10/dist-packages (from dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.24.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (1.6.0)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.10/dist-packages (from dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.2.36)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from hdmf<4,>=2.5.6->ndx-pose->keypoint-moseq) (4.23.0)
# Requirement already satisfied: ruamel-yaml>=0.16 in /usr/local/lib/python3.10/dist-packages (from hdmf<4,>=2.5.6->ndx-pose->keypoint-moseq) (0.18.8)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh->keypoint-moseq) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.56.4->jax-moseq>=0.2.2->keypoint-moseq) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.8.4->keypoint-moseq) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->panel==0.14.4->keypoint-moseq) (0.5.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->keypoint-moseq) (5.7.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->keypoint-moseq) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->holoviews[recommended]->keypoint-moseq) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->holoviews[recommended]->keypoint-moseq) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook->holoviews[recommended]->keypoint-moseq) (7.16.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->holoviews[recommended]->keypoint-moseq) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->holoviews[recommended]->keypoint-moseq) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->holoviews[recommended]->keypoint-moseq) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->holoviews[recommended]->keypoint-moseq) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->holoviews[recommended]->keypoint-moseq) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->panel==0.14.4->keypoint-moseq) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->panel==0.14.4->keypoint-moseq) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->panel==0.14.4->keypoint-moseq) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->panel==0.14.4->keypoint-moseq) (2024.12.14)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (3.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf<4,>=2.5.6->ndx-pose->keypoint-moseq) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf<4,>=2.5.6->ndx-pose->keypoint-moseq) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf<4,>=2.5.6->ndx-pose->keypoint-moseq) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->keypoint-moseq) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->holoviews[recommended]->keypoint-moseq) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->holoviews[recommended]->keypoint-moseq) (4.12.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->holoviews[recommended]->keypoint-moseq) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->holoviews[recommended]->keypoint-moseq) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->holoviews[recommended]->keypoint-moseq) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->holoviews[recommended]->keypoint-moseq) (0.10.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->holoviews[recommended]->keypoint-moseq) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->holoviews[recommended]->keypoint-moseq) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->holoviews[recommended]->keypoint-moseq) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.4.0->holoviews[recommended]->keypoint-moseq) (0.2.13)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel-yaml>=0.16->hdmf<4,>=2.5.6->ndx-pose->keypoint-moseq) (0.2.12)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->holoviews[recommended]->keypoint-moseq) (21.2.0)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from optax->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.10/dist-packages (from optax->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.1.88)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.10/dist-packages (from optax->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (1.11.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (3.5.0)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (3.1.0)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.6.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability->dynamax>=0.1.2->jax-moseq>=0.2.2->keypoint-moseq) (0.1.8)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->holoviews[recommended]->keypoint-moseq) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->holoviews[recommended]->keypoint-moseq) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->holoviews[recommended]->keypoint-moseq) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->holoviews[recommended]->keypoint-moseq) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->holoviews[recommended]->keypoint-moseq) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->holoviews[recommended]->keypoint-moseq) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->holoviews[recommended]->keypoint-moseq) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->holoviews[recommended]->keypoint-moseq) (1.2.2)
# Mounted at /content/drive

# %% [markdown]
# ### Option 1: Use our example dataset

# %%
import gdown
url = 'https://drive.google.com/uc?id=1JGyS9MbdS3MtrlYnh4xdEQwe2bYoCuSZ'
output = 'dlc_example_project.zip'
gdown.download(url, output, quiet=False)
! unzip dlc_example_project.zip

data_dir = "dlc_example_project"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JGyS9MbdS3MtrlYnh4xdEQwe2bYoCuSZ
# From (redirected): https://drive.google.com/uc?id=1JGyS9MbdS3MtrlYnh4xdEQwe2bYoCuSZ&confirm=t&uuid=1de20bda-c848-42e4-8821-aebcc5d56a0f
# To: /content/dlc_example_project.zip
# 100%|██████████| 302M/302M [00:01<00:00, 155MB/s]
# Archive:  dlc_example_project.zip
# replace dlc_example_project/config.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dlc_example_project/videos/21_12_10_def6a_3.top.ir.mp4? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dlc_example_project/videos/22_04_26_cage4_1_1.top.ir.mp4? [y]es, [n]o, [A]ll, [N]one, [r]ename: None

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ### Option 2: Use your own data
# Upload your data to google drive and then change the following path as needed

# %%
# data_dir = "/content/drive/MyDrive/MY_DATA_DIRECTORY"

# %% [markdown]
# # Project setup
# Create a new project directory with a keypoint-MoSeq `config.yml` file.

# %%
import keypoint_moseq as kpms

project_dir = '/content/drive/MyDrive/demo_project/'
config = lambda: kpms.load_config(project_dir)

# %%
rat7m_project_dir = '/content/drive/MyDrive/rat7m_project/'
rat7m_config = lambda: kpms.load_config(rat7m_project_dir)

# %% [markdown]
# ### Option 1: Setup from DeepLabCut

# %%
dlc_config = os.path.join(data_dir, 'config.yaml')
kpms.setup_project(project_dir, deeplabcut_config=dlc_config)
# Out:
# The directory `/content/drive/MyDrive/demo_project/` already exists.
# Use `overwrite=True` or pick a different name

# %% [markdown]
# ### Option 2: Setup from SLEAP

# %%
# choose a .h5 file for one of your recordings
# sleap_file = os.path.join(data_dir, 'SLEAP_FILE_NAME')
# kpms.setup_project(project_dir, sleap_file=sleap_file)

# %% [markdown]
# ### Options 3: Manual setup

# %%
# bodyparts=[
#     'tail', 'spine4', 'spine3', 'spine2', 'spine1',
#     'head', 'nose', 'right ear', 'left ear']

# skeleton=[
#     ['tail', 'spine4'],
#     ['spine4', 'spine3'],
#     ['spine3', 'spine2'],
#     ['spine2', 'spine1'],
#     ['spine1', 'head'],
#     ['nose', 'head'],
#     ['left ear', 'head'],
#     ['right ear', 'head']]

# video_dir = os.path.join(data_dir, 'videos')

# kpms.setup_project(
#     project_dir,
#     video_dir=video_dir,
#     bodyparts=bodyparts,
#     skeleton=skeleton)

# %% [markdown]
# ## Edit the config file
#
# The config can be edited in a text editor or using the function `kpms.update_config`, as shown below. In general, the following parameters should be specified for each project:
#
# - `bodyparts` (name of each keypoint; automatically imported from SLEAP/DeepLabCut)
# - `use_bodyparts` (subset of bodyparts to use for modeling, set to all bodyparts by default; for mice we recommend excluding the tail)
# - `anterior_bodyparts` and `posterior_bodyparts` (used for rotational alignment)
# - `video_dir` (directory with videos of each experiment)
#
# Edit the config as follows for the [example DeepLabCut dataset](https://drive.google.com/drive/folders/1UNHQ_XCQEKLPPSjGspRopWBj6-YNDV6G?usp=share_link):

# %%
kpms.update_config(
    project_dir,
    video_dir=os.path.join(data_dir, 'videos'),
    anterior_bodyparts=['nose'],
    posterior_bodyparts=['spine4'],
    use_bodyparts=[
        'spine4', 'spine3', 'spine2', 'spine1',
        'head', 'nose', 'right ear', 'left ear'])

# %% [markdown]
# ## Load data
#
# The code below shows how to load keypoint detections from DeepLabCut. To load other formats, replace `'deeplabcut'` in the example with one of `'sleap', 'anipose', 'sleap-anipose', 'nwb'`. For other formats, see the [FAQ](https://keypoint-moseq.readthedocs.io/en/latest/FAQs.html#loading-keypoint-tracking-data).

# %%
# load data (e.g. from DeepLabCut)
keypoint_data_path = os.path.join(data_dir, 'videos') # can be a file, a directory, or a list of files
coordinates, confidences, bodyparts = kpms.load_keypoints(keypoint_data_path, 'deeplabcut')

# format data for modeling
data, metadata = kpms.format_data(coordinates, confidences, **config())
# Out:
# Loading keypoints: 100%|████████████████| 10/10 [00:00<00:00, 20.42it/s]

# %%
print(data.keys())
print(data['mask'].shape)
print(coordinates.keys())
print(coordinates['21_11_8_one_mouse.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000'].shape)
print(confidences.keys())
print(confidences['21_11_8_one_mouse.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000'].shape)
# Out:
# dict_keys(['Y', 'conf', 'mask'])
# (70, 10030)
# dict_keys(['21_11_8_one_mouse.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_10_def6a_3.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_10_def6b_3.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '22_27_04_cage4_mouse2_0.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '22_04_26_cage4_0.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_2_def6a_1.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '22_04_26_cage4_1_1.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_10_def6a_1_1.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '22_04_26_cage4_0_2.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_2_def6b_2.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000'])
# (71524, 9, 2)
# dict_keys(['21_11_8_one_mouse.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_10_def6a_3.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_10_def6b_3.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '22_27_04_cage4_mouse2_0.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '22_04_26_cage4_0.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_2_def6a_1.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '22_04_26_cage4_1_1.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_10_def6a_1_1.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '22_04_26_cage4_0_2.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000', '21_12_2_def6b_2.top.irDLC_resnet50_moseq_exampleAug21shuffle1_500000'])
# (71524, 9)

# %% [markdown]
# Load data from mat

# %%
import scipy.io
rat7m_data_dir = 'Rat7M'
rat7m_keypoint_data_path = os.path.join(rat7m_data_dir, 'mocap-s1-d1.mat')
mat_data = scipy.io.loadmat(rat7m_keypoint_data_path)

# %%
# print(mat_data['mocap'][0])
body_parts = ['HeadF','HeadB','HeadL','SpineF','SpineM','SpineL','Offset1',\
              'Offset2','HipL','HipR','ElbowL','ArmL','ShoulderL','ShoulderR',
              'ElbowR','ArmR','KneeR','KneeL','ShinL','ShinR'  ]
assert len(body_parts) == 20
for name in body_parts:
  print(f'- {name}')
# Out:
# - HeadF
# - HeadB
# - HeadL
# - SpineF
# - SpineM
# - SpineL
# - Offset1
# - Offset2
# - HipL
# - HipR
# - ElbowL
# - ArmL
# - ShoulderL
# - ShoulderR
# - ElbowR
# - ArmR
# - KneeR
# - KneeL
# - ShinL
# - ShinR

# %%
print(len(mat_data['mocap'][0][0]))
# Out:
# 20

# %%
import numpy as np
coordinates_s1d1 = np.stack(mat_data['mocap'][0][0],1)
confidences_s1d1 = np.ones((coordinates_s1d1.shape[0], coordinates_s1d1.shape[1]))
coordinates_s1d1 = {'s1d1': coordinates_s1d1}
confidences_s1d1 = {'s1d1': confidences_s1d1}
print(coordinates_s1d1['s1d1'].shape)
# Out:
# (126000, 20, 3)

# %%
rat7m_data, rat7m_metadata = kpms.format_data(coordinates_s1d1, confidences_s1d1, **rat7m_config())

# %% [markdown]
# ## Calibration [disabled in colab]
#
# The purpose of calibration is to learn the relationship between error and keypoint confidence scores. The resulting regression coefficients (`slope` and `intercept`) are used during modeling to set the noise prior on a per-frame, per-keypoint basis. **This step is disabled in colab**. In any case it can safely be skipped since the default parameters are fine for most datasets.

# %% [markdown]
# ## Fit PCA
#
# Run the cell below to fit a PCA model to aligned and centered keypoint coordinates.
#
# - The model is saved to ``{project_dir}/pca.p`` and can be reloaded using ``kpms.load_pca``.
# - Two plots are generated: a cumulative [scree plot](https://en.wikipedia.org/wiki/Scree_plot) and a depiction of each PC, where translucent nodes/edges represent the mean pose and opaque nodes/edges represent a perturbation in the direction of the PC.
# - After fitting, edit `latent_dimension` in the config. This determines the dimension of the pose trajectory used to fit keypoint-MoSeq. A good heuristic is the number of dimensions needed to explain 90% of variance, or 10 dimensions - whichever is lower.

# %%
pca = kpms.fit_pca(**rat7m_data, **rat7m_config())
kpms.save_pca(pca, rat7m_project_dir)

kpms.print_dims_to_explain_variance(pca, 0.9)
kpms.plot_scree(pca, project_dir=rat7m_project_dir)
kpms.plot_pcs(pca, project_dir=rat7m_project_dir, **rat7m_config())

# use the following to load an already fit model
# pca = kpms.load_pca(project_dir)
# Out:
# >=90.0% of variance exlained by 9 components.
# Saved interactive plot to /content/drive/MyDrive/rat7m_project/pcs.html
# <iframe
#     scrolling="no"
#     width="100%"
#     height="420"
#     src="iframe_figures/figure_70.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
kpms.update_config(rat7m_project_dir, latent_dim=4)

# %% [markdown]
# # Model fitting
#
# Fitting a keypoint-MoSeq model involves:
# 1. **Initialization:** Auto-regressive (AR) parameters and syllable sequences are randomly initialized using pose trajectories from PCA.
# 2. **Fitting an AR-HMM:** The AR parameters, transition probabilities and syllable sequences are iteratively updated through Gibbs sampling.
# 3. **Fitting the full model:** All parameters, including both the AR-HMM as well as centroid, heading, noise-estimates and continuous latent states (i.e. pose trajectories) are iteratively updated through Gibbs sampling. This step is especially useful for noisy data.
# 4. **Extracting model results:** The learned states of the model are parsed and saved to disk for vizualization and downstream analysis.
# 4. **[Optional] Applying the trained model:** The learned model parameters can be used to infer a syllable sequences for additional data.
#
# ## Setting kappa
#
# Most users will need to adjust the **kappa** hyperparameter to achieve the desired distribution of syllable durations. For this tutorial we chose kappa values that yielded a median syllable duration of 400ms (12 frames). Most users will need to tune kappa to their particular dataset. Higher values of kappa lead to longer syllables. **You will need to pick two kappas: one for AR-HMM fitting and one for the full model.**
# - We recommend iteratively updating kappa and refitting the model until the target syllable time-scale is attained.
# - Model fitting can be stopped at any time by interrupting the kernel, and then restarted with a new kappa value.
# - The full model will generally require a lower value of kappa to yield the same target syllable durations.
# - To adjust the value of kappa in the model, use `kpms.update_hypparams` as shown below. Note that this command only changes kappa in the model dictionary, not the kappa value in the config file. The value in the config is only used during model initialization.

# %% [markdown]
# ## Initialization

# %%
# initialize the model
model = kpms.init_model(rat7m_data, pca=pca, **rat7m_config())

# optionally modify kappa
# model = kpms.update_hypparams(model, kappa=NUMBER)

# %% [markdown]
# ## Fitting an AR-HMM
#
# In addition to fitting an AR-HMM, the function below:
# - generates a name for the model and a corresponding directory in `project_dir`
# - saves a checkpoint every 25 iterations from which fitting can be restarted
# - plots the progress of fitting every 25 iterations, including
#     - the distributions of syllable frequencies and durations for the most recent iteration
#     - the change in median syllable duration across fitting iterations
#     - a sample of the syllable sequence across iterations in a random window

# %%
num_ar_iters = 50

model, model_name = kpms.fit_model(
    model, rat7m_data, rat7m_metadata, rat7m_project_dir,
    ar_only=True, num_iters=num_ar_iters)
# Out:
# Outputs will be saved to
# /content/drive/MyDrive/rat7m_project/2025_01_02-19_27_34
#  49%|█████████████████▏                 | 25/51 [00:57<00:51,  1.98s/it]
#  98%|██████████████████████████████████▎| 50/51 [01:50<00:02,  2.13s/it]
# 100%|███████████████████████████████████| 51/51 [01:54<00:00,  2.24s/it]

# %% [markdown]
# ## Fitting the full model
#
# The following code fits a full keypoint-MoSeq model using the results of AR-HMM fitting for initialization. If using your own data, you may need to try a few values of kappa at this step.

# %%
# load model checkpoint
model, data, metadata, current_iter = kpms.load_checkpoint(
    rat7m_project_dir, model_name, iteration=num_ar_iters)

# modify kappa to maintain the desired syllable time-scale
model = kpms.update_hypparams(model, kappa=1e4)

# run fitting for an additional 500 iters
model = kpms.fit_model(
    model, data, metadata, rat7m_project_dir, model_name, ar_only=False,
    start_iter=current_iter, num_iters=current_iter+500)[0]
# Out:
# Outputs will be saved to
# /content/drive/MyDrive/rat7m_project/2025_01_02-19_27_34
#   0%|                                           | 0/501 [00:38<?, ?it/s]
# Early termination of fitting: user interruption

# %% [markdown]
# ## Sort syllables by frequency
#
# Permute the states and parameters of a saved checkpoint so that syllables are labeled in order of frequency (i.e. so that `0` is the most frequent, `1` is the second most, and so on).

# %%
# modify a saved checkpoint so syllables are ordered by frequency
kpms.reindex_syllables_in_checkpoint(project_dir, model_name);

# %% [markdown]
# ```{warning}
# Reindexing is only applied to the checkpoint file. Therefore, if you perform this step after extracting the modeling results or generating vizualizations, then those steps must be repeated.
# ```

# %% [markdown]
# ## Extract model results
#
# Parse the modeling results and save them to `{project_dir}/{model_name}/results.h5`. The results are stored as follows, and can be reloaded at a later time using `kpms.load_results`. Check the docs for an [in-depth explanation of the modeling results](https://keypoint-moseq.readthedocs.io/en/latest/FAQs.html#interpreting-model-outputs).
# ```
#     results.h5
#     ├──recording_name1
#     │  ├──syllable      # syllable labels (z)
#     │  ├──latent_state  # inferred low-dim pose state (x)
#     │  ├──centroid      # inferred centroid (v)
#     │  └──heading       # inferred heading (h)
#     ⋮
# ```

# %%
# load the most recent model checkpoint
model, data, metadata, current_iter = kpms.load_checkpoint(project_dir, model_name)

# extract results
results = kpms.extract_results(model, metadata, project_dir, model_name)

# %% [markdown]
# ### [Optional] Save results to csv
#
# After extracting to an h5 file, the results can also be saved as csv files. A separate file will be created for each recording and saved to `{project_dir}/{model_name}/results/`.

# %%
# optionally save results as csv
kpms.save_results_as_csv(results, project_dir, model_name)

# %% [markdown]
# ## Apply to new data
#
# The code below shows how to apply a trained model to new data. This is useful if you have performed new experiments and would like to maintain an existing set of syllables. The results for the new experiments will be added to the existing `results.h5` file. **This step is optional and can be skipped if you do not have new data to add**.

# %%
# load the most recent model checkpoint and pca object
# model = kpms.load_checkpoint(project_dir, model_name)[0]

# # load new data (e.g. from deeplabcut)
# new_data = 'path/to/new/data/' # can be a file, a directory, or a list of files
# coordinates, confidences, bodyparts = kpms.load_keypoints(new_data, 'deeplabcut')
# data, metadata = kpms.format_data(coordinates, confidences, **config())

# # apply saved model to new data
# results = kpms.apply_model(model, data, metadata, project_dir, model_name, **config())

# optionally rerun `save_results_as_csv` to export the new results
# kpms.save_results_as_csv(results, project_dir, model_name)

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Trajectory plots
# Generate plots showing the median trajectory of poses associated with each given syllable.

# %%
results = kpms.load_results(project_dir, model_name)
kpms.generate_trajectory_plots(coordinates, results, project_dir, model_name, **config())

# %% [markdown]
# ## Grid movies
# Generate video clips showing examples of each syllable.
#
# *Note: the code below will only work with 2D data. For 3D data, see the [FAQ](https://keypoint-moseq.readthedocs.io/en/latest/FAQs.html#making-grid-movies-for-3d-data).*

# %%
kpms.generate_grid_movies(results, project_dir, model_name, coordinates=coordinates, **config());

# %% [markdown]
# ## Syllable Dendrogram
# Plot a dendrogram representing distances between each syllable's median trajectory.

# %%
kpms.plot_similarity_dendrogram(coordinates, results, project_dir, model_name, **config())
